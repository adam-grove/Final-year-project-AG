# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv(r"C:\Users\adamg\OneDrive - The University of Liverpool\Project Work\MALDIquant\MALDIquant_Feature_Values.csv")
matrix = df.T
matrix.to_csv("MALDIquant_Feature_Matrix.csv",header = False)


test = pd.read_csv(r"C:\Users\adamg\OneDrive - The University of Liverpool\Project Work\MALDIquant\MALDIquant_Feature_Matrix.csv")
test
# Out:
#       Unnamed: 0    P1_t0h   P1_t10h   P1_t11h    P1_t1h    P1_t2h    P1_t3h  \
# 0     116.143164  0.003139  0.003377  0.003350  0.003393  0.003354  0.003426
# 1     117.135885  0.001501  0.001411  0.001455  0.001497  0.001467  0.001432
# 2     119.085244  0.001432  0.002463  0.001730  0.001339  0.001567  0.001799
# 3     168.135917  0.000481  0.000452  0.000447  0.000452  0.000272  0.000549
# 4     186.215314  0.001453  0.000532  0.000688  0.001182  0.001006  0.001128
# ..           ...       ...       ...       ...       ...       ...       ...
# 472  1760.749787  0.001717  0.002424  0.001918  0.001762  0.002575  0.002026
# 473  1761.743210  0.000985  0.001326  0.002586  0.001414  0.001752  0.001717
# 474  1762.730958  0.001415  0.001189  0.001197  0.001243  0.002104  0.001839
# 475  1766.551801  0.000588  0.002489  0.001496  0.001378  0.001268  0.001244
# 476  1767.543409  0.001123  0.002840  0.001967  0.001819  0.001681  0.001317
#
# ...

# %%
maow =pd.read_csv(r"C:\Users\adamg\OneDrive - The University of Liverpool\Project Work\MZmine\MZmine_Feature_Matrix.csv")

maow
# Out:
#       id  P1_t1h  P10_t1h  P10_t11h  P10_t10h  P10_t9h    P10_t5h  P10_t0h  \
# 0      1     NaN      NaN       NaN       NaN      NaN        NaN      NaN
# 1      2     NaN      NaN       NaN       NaN      NaN        NaN      NaN
# 2      3     NaN      NaN       NaN       NaN      NaN        NaN      NaN
# 3      4     NaN      NaN       NaN       NaN      NaN        NaN      NaN
# 4      5     NaN      NaN       NaN       NaN      NaN        NaN      NaN
# ..   ...     ...      ...       ...       ...      ...        ...      ...
# 976  977     NaN      NaN       NaN       NaN      NaN  907.77169      NaN
# 977  978     NaN      NaN       NaN       NaN      NaN  933.78764      NaN
# 978  979     NaN      NaN       NaN       NaN      NaN        NaN      NaN
# 979  980     NaN      NaN       NaN       NaN      NaN        NaN      NaN
# 980  981     NaN      NaN       NaN       NaN      NaN        NaN      NaN
#
# ...
